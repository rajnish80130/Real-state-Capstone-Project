# %% [markdown]
# <a href="https://colab.research.google.com/github/rajnish80130/Real-state-Capstone-Project/blob/main/merge_flats_and_house_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
flats = pd.read_csv('/content/flats_cleaned.csv')
house = pd.read_csv('/content/house_cleaned.csv')

# %%
print(flats.shape)
print(house.shape)
# Out:
# (2997, 20)
# (958, 20)

# %%
flats.head()
# Out:
#                      property_name property_type                 society  \
# 0     2 BHK Flat in Krishna Colony          flat  maa bhagwati residency
# 1        2 BHK Flat in Ashok Vihar          flat            apna enclave
# 2              2 BHK Flat in Sohna          flat  tulsiani easy in homes
# 3  2 BHK Flat in Sector 61 Gurgaon          flat     smart world orchard
# 4  2 BHK Flat in Sector 92 Gurgaon          flat        parkwood westend
#
#    price  price_per_sqft    area                            areaWithType  \
# 0   0.45          5000.0   900.0          Carpet area: 900 (83.61 sq.m.)
# 1   0.50          7692.0   650.0          Carpet area: 650 (60.39 sq.m.)
# 2   0.40          6722.0   595.0          Carpet area: 595 (55.28 sq.m.)
# 3   1.47         12250.0  1200.0        Carpet area: 1200 (111.48 sq.m.)
# 4   0.70          5204.0  1345.0  Super Built up area 1345(124.95 sq.m.)
#
#    bedRoom  bathroom balcony additionalRoom  \
# ...

# %%
house.head()
# Out:
#                                       property_name property_type  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon         house
# 1  5 Bedroom House for sale in Sector 21A Faridabad         house
# 2  10 Bedroom House for sale in Sushant Lok Phase 1         house
# 3    21 Bedroom House for sale in Sector 54 Gurgaon         house
# 4  12 Bedroom House for sale in Sushant Lok Phase 1         house
#
#             society  price  price_per_sqft    area  \
# 0  bptp visionnaire   5.25           20115  2610.0
# 1       Independent   5.70          105751   539.0
# 2       Independent   2.10           38251   549.0
# 3       Independent   5.00           43066  1161.0
# 4       Independent   3.00           53763   558.0
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+
# 1   Plot area 539(50.07 sq.m.)        5         4       2
# 2       Plot area 61(51 sq.m.)       10        10      3+
# ...

# %%
df = pd.concat([flats,house],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                       property_name property_type                  society  \
# 0  3 BHK Flat in Sector 113 Gurgaon          flat  la vida by tata housing
# 1   3 BHK Flat in Sector 78 Gurgaon          flat     umang monsoon breeze
# 2   4 BHK Flat in sector 58 Gurgaon          flat      ireo the grand arch
# 3  3 BHK Flat in Sector 107 Gurgaon          flat            m3m woodshire
# 4   4 BHK Flat in Sector 22 Gurgaon          flat       ambience creacions
#
#    price  price_per_sqft    area  \
# 0   3.00         14285.0  2100.0
# 1   0.88          4746.0  1854.0
# 2   4.85         16934.0  2864.0
# 3   1.49          6310.0  2361.0
# 4   6.16         20533.0  3000.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 2691(250 sq.m.)Built Up ar...        3         3
# 1  Super Built up area 1854(172.24 sq.m.)Built Up...        3         4
# 2                   Carpet area: 2864 (266.07 sq.m.)        4         5
# ...

# %%
df.to_csv('gurgaon_properties.csv',index=False)
