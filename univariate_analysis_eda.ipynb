# %% [markdown]
# <a href="https://colab.research.google.com/github/rajnish80130/Real-state-Capstone-Project/blob/main/univariate_analysis_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/gurgaon_properties_cleaned_v2.csv')
df.head()
# Out:
#   property_type                  society      sector  price  price_per_sqft  \
# 0          flat  la vida by tata housing  sector 113   3.00         14285.0
# 1          flat     umang monsoon breeze   sector 78   0.88          4746.0
# 2          flat      ireo the grand arch   sector 58   4.85         16934.0
# 3          flat            m3m woodshire  sector 107   1.49          6310.0
# 4          flat       ambience creacions   sector 22   6.16         20533.0
#
#      area                                       areaWithType  bedRoom  \
# 0  2100.0  Super Built up area 2691(250 sq.m.)Built Up ar...        3
# 1  1854.0  Super Built up area 1854(172.24 sq.m.)Built Up...        3
# 2  2864.0                   Carpet area: 2864 (266.07 sq.m.)        4
# 3  2361.0             Super Built up area 2361(219.34 sq.m.)        3
# 4  3000.0                   Carpet area: 3000 (278.71 sq.m.)        4
#
#    bathroom balcony  ...  super_built_up_area built_up_area carpet_area  \
# ...

# %%
df.shape
# Out:
# (3799, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3799 entries, 0 to 3798
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_type        3799 non-null   object
#  1   society              3798 non-null   object
#  2   sector               3799 non-null   object
#  3   price                3798 non-null   float64
#  4   price_per_sqft       3798 non-null   float64
#  5   area                 3798 non-null   float64
#  6   areaWithType         3799 non-null   object
#  7   bedRoom              3799 non-null   int64
#  8   bathroom             3799 non-null   int64
#  9   balcony              3799 non-null   object
#  10  floorNum             3779 non-null   float64
#  11  facing               2699 non-null   object
#  12  agePossession        3799 non-null   object
#  13  super_built_up_area  1915 non-null   float64
#  14  built_up_area        1729 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     1
# price_per_sqft            1
# area                      1
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 20
# facing                 1100
# agePossession             0
# super_built_up_area    1884
# built_up_area          2070
# carpet_area            1857
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(138)

# %%
df[df.duplicated()].head()
# Out:
#     property_type                               society      sector  price  \
# 259          flat  shapoorji pallonji joyville gurugram  sector 102   0.95
# 445          flat                           birla navya  sector 63a   3.70
# 569          flat                       the close north   sector 50   3.00
# 599          flat            ramprastha the edge towers  sector 37d   1.00
# 659          flat                                godrej   sector 79   2.00
#
#      price_per_sqft    area  \
# 259         10383.0   915.0
# 445         15416.0  2400.0
# 569         11516.0  2605.0
# 599          5649.0  1770.0
# 659          8453.0  2366.0
#
#                                           areaWithType  bedRoom  bathroom  \
# 259  Built Up area: 915 (85.01 sq.m.)Carpet area: 8...        2         2
# 445                   Carpet area: 2400 (222.97 sq.m.)        3         3
# 569             Super Built up area 2605(242.01 sq.m.)        3         3
# ...

# %% [markdown]
# ###i watch through naked eye then find 0 duplicated values

# %%
#property_type
df['property_type'].value_counts()
# Out:
# property_type
# flat     2943
# house     856
# Name: count, dtype: int64

# %%
df['property_type'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['property_type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='property_type'>

# %% [markdown]
# # Observations
#
#
# *       Flats are in majority(75 percent) and there are less number of houses(~25 percent)
#
# *   No missing values

# %%
#society
df['society'].value_counts().shape
# Out:
# (675,)

# %%
df['society'].value_counts()
# Out:
# society
# Independent                             486
# tulip violet                             75
# ss the leaf                              74
# shapoorji pallonji joyville gurugram     45
# dlf new town heights                     44
#                                        ...
# dlf floors phase 3                        1
# professional society                      1
# dlf city plots phase 4                    1
# ansal florence super                      1
# park view apartments                      1
# Name: count, Length: 675, dtype: int64

# %%
df[df['society'] != 'Independent']['society'].value_counts(normalize=True).cumsum().head(75)
# Out:
# society
# tulip violet                            0.022645
# ss the leaf                             0.044988
# shapoorji pallonji joyville gurugram    0.058575
# dlf new town heights                    0.071860
# signature global park                   0.083031
#                                           ...
# mvn athens                              0.486111
# corona optus                            0.490338
# ireo the corridors                      0.494263
# emaar mgf marbella                      0.498188
# puri emerald bay                        0.502114
# Name: proportion, Length: 75, dtype: float64

# %%
society_counts = df['society'].value_counts()

# Frequency distribution for societies
frequency_bins = {
    "Very High (>100)": int((society_counts > 100).sum()),
    "High (50-100)": int(((society_counts >= 50) & (society_counts <= 100)).sum()),
    "Average (10-49)": int(((society_counts >= 10) & (society_counts < 50)).sum()),
    "Low (2-9)": int(((society_counts > 1) & (society_counts < 10)).sum()),
    "Very Low (1)": int((society_counts == 1).sum())
}
frequency_bins
# Out:
# {'Very High (>100)': 1,
#  'High (50-100)': 2,
#  'Average (10-49)': 97,
#  'Low (2-9)': 284,
#  'Very Low (1)': 291}

# %%
#top 10 society
df[df['society'] != 'Independent']['society'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='society'>

# %%
int(df['society'].isnull().sum())
# Out:
# 1

# %%
df[df['society'].isnull()]
# Out:
#     property_type society     sector  price  price_per_sqft    area  \
# 357          flat     NaN  sector 78    0.6          3692.0  1625.0
#
#                            areaWithType  bedRoom  bathroom balcony  ...  \
# 357  Built Up area: 1625 (150.97 sq.m.)        2         2       0  ...
#
#      super_built_up_area built_up_area carpet_area  study room  servant room  \
# 357                  NaN        1625.0         NaN           0             0
#
#      store room  pooja room  others  furnishing_type  luxury_score
# 357           0           0       0                0             0
#
# [1 rows x 23 columns]

# %%
df.dropna(subset='society',inplace=True)

# %%
df['society'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Observations
#
# *   Around 13% properties comes under independent tag.
# *   There are 675 societies.
# *   The top 75 societies have 50 percent of the preperties and the rest 50 percent of the properties come under the remaining 600 societies
#   *   Very High (>100): Only 1 society has more than 100 listings(Independent House).
#   *   High (50-100): 2 societies have between 50 to 100 listings.
#   *   Average (10-49): 92 societies fall in this range with 10 to 49 listings each.
#   *   Low (2-9): 273 societies have between 2 to 9 listings.
#   *   Very Low (1): A significant number, 308 societies, have only 1 listing.
# *  0 Missing Values

# %%
#sector
df['sector'].value_counts().shape
# Out:
# (113,)

# %%
df['sector'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['sector'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='sector'>

# %%
# Frequency distribution for sectors
sector_counts = df['sector'].value_counts()

sector_frequency_bins = {
    "Very High (>100)": int((sector_counts > 100).sum()),
    "High (50-100)": int(((sector_counts >= 50) & (sector_counts <= 100)).sum()),
    "Average (10-49)": int(((sector_counts >= 10) & (sector_counts < 50)).sum()),
    "Low (2-9)": int(((sector_counts > 1) & (sector_counts < 10)).sum()),
    "Very Low (1)": int((sector_counts == 1).sum())
}

sector_frequency_bins
# Out:
# {'Very High (>100)': 4,
#  'High (50-100)': 25,
#  'Average (10-49)': 62,
#  'Low (2-9)': 21,
#  'Very Low (1)': 1}

# %% [markdown]
# # Observations
#
# *   There are a total of 113 unique sectors in the dataset.
# *   Frequency distribution of sectors:
#   *   Very High (>100): 4 sectors have more than 100 listings.
#   *   High (50-100): 25 sectors have between 50 to 100 listings.
#   *   Average (10-49): A majority, 62 sectors, fall in this range with 10 to 49 listings each.
#   *   Low (2-9): 16 sectors have between 2 to 9 listings.
#   *   Very Low (1): Interestingly, there are only sectors with only 1 listing.
# *   0 Mising Values

# %%
#price
df['price'].isnull().sum()
# Out:
# np.int64(1)

# %%
df[df['price'].isnull()]
# Out:
#      property_type                            society     sector  price  \
# 1929          flat  signature global orchard avenue 2  sector 93    NaN
#
#       price_per_sqft  area                       areaWithType  bedRoom  \
# 1929             NaN   NaN  Carpet area: 577.11 (53.62 sq.m.)        2
#
#       bathroom balcony  ...  super_built_up_area built_up_area carpet_area  \
# 1929         2       3  ...                  NaN           NaN  577.160318
#
#       study room  servant room  store room  pooja room  others  \
# 1929           0             0           0           0       0
#
#       furnishing_type  luxury_score
# 1929                0           104
#
# [1 rows x 23 columns]

# %%
df['price'].describe()
# Out:
# count    3797.000000
# mean        2.518925
# std         2.961386
# min         0.070000
# 25%         0.940000
# 50%         1.500000
# 75%         2.750000
# max        31.500000
# Name: price, dtype: float64

# %%
sns.histplot(df['price'],kde=True,bins=50)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.boxplot(df['price'],color='lightgreen')
plt.grid()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['price'].dropna(), bins=50, kde=True)
plt.axvline(df['price'].mean(), color='red', linestyle='--', label='Mean')
plt.axvline(df['price'].median(), color='green', linestyle='--', label='Median')
plt.legend()
plt.title("Distribution of Property Prices")
plt.xlabel("Price (Crores)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Descriptive Statistics:
#
# * Count: There are 3,660 non-missing price entries.
# * Mean Price: The average price is approximately 2.53 crores.
# * Median Price: The median (or 50th percentile) price is 1.52 crores.
# * Standard Deviation: The prices have a standard deviation of 2.98, indicating variability in the prices.
# * Range: Prices range from a minimum of 0.07 crores to a maximum of 31.5 crores.
# * IQR: The interquartile range (difference between 75th and 25th percentile) is from 0.95 crores to 2.75 crores.
#
# # Visualizations:
#
#   * Distribution: The histogram indicates that most properties are priced in the lower range (below 5 crores), with a few properties going beyond 10 crores.
#   * Box Plot: The box plot showcases the spread of the data and potential outliers. Properties priced above approximately 10 crores might be considered outliers as they lie beyond the upper whisker of the box plot.
#
#
# ### Missing Values: There are 0 missing values in the price column.

# %%
# Skewness and Kurtosis
skewness = df['price'].skew()
kurtosis = df['price'].kurt()

print(skewness,kurtosis)
# Out:
# 3.2886921870603314 15.031180800650034

# %% [markdown]
# **Skewness**: The price distribution has a skewness of approximately 3.28, indicating a positive skew. This means that the distribution tail is skewed to the right, which aligns with our observation from the histogram where most properties have prices on the lower end with a few high-priced properties.
#
#
# **Kurtosis**: The kurtosis value is approximately 15.03. A kurtosis value greater than 3 indicates a distribution with heavier tails and more outliers compared to a normal distribution.

# %%
# Quantile Analysis
quantiles = df['price'].quantile([0.01, 0.05, 0.95, 0.99])

quantiles
# Out:
# 0.01     0.250
# 0.05     0.370
# 0.95     8.492
# 0.99    15.116
# Name: price, dtype: float64

# %% [markdown]
# # Quantile Analysis:
#
# * 1% Quantile: Only 1% of properties are priced below 0.25 crores.
# * 5% Quantile: 5% of properties are priced below 0.37 crores.
# * 95% Quantile: 95% of properties are priced below 8.5 crores.
# * 99% Quantile: 99% of properties are priced below 15.116 crores, indicating that very few properties are priced above this value.

# %%
# Identify potential outliers using IQR method
Q1 = df['price'].describe()['25%']
Q3 = df['price'].describe()['75%']
IQR = Q3 - Q1

IQR
# Out:
# np.float64(1.81)

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(lower_bound, upper_bound)
# Out:
# -1.775 5.465

# %%
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]
outliers.shape
# Out:
# (435, 23)

# %%
outliers['price'].describe()
# Out:
# count    435.000000
# mean       9.221540
# std        4.057075
# min        5.490000
# 25%        6.440000
# 50%        8.000000
# 75%       10.655000
# max       31.500000
# Name: price, dtype: float64

# %%
outliers['price'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Outliers Analysis (using IQR method):
#
# * Based on the IQR method, there are 435 properties considered as outliers.
# * These outliers have an average price of approximately 9.22 crores.
# * The range for these outliers is from 5.49 crores to 31.5 crores.

# %%
# price binning
bins = [0, 1, 2, 3, 5, 10, 20, 50]
bin_labels = ["0-1", "1-2", "2-3", "3-5", "5-10", "10-20", "20-50"]
pd.cut(df['price'], bins=bins, labels=bin_labels, right=False).value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='price'>

# %% [markdown]
# * The majority of properties are priced in the "1-2 crores" and "2-3 crores" ranges.
# * There's a significant drop in the number of properties priced above "5 crores."

# %%
# ecdf plot
ecdf = df['price'].value_counts().sort_index().cumsum() / len(df['price'])
plt.plot(ecdf.index, ecdf, marker='.', linestyle='none')
plt.grid()

# %%
plt.figure(figsize=(15, 6))

# Distribution plot without log transformation
plt.subplot(1, 2, 1)
sns.histplot(df['price'], kde=True, bins=50, color='skyblue')
plt.title('Distribution of Prices (Original)')
plt.xlabel('Price (in Crores)')
plt.ylabel('Frequency')

# Distribution plot with log transformation
plt.subplot(1, 2, 2)
sns.histplot(np.log1p(df['price']), kde=True, bins=50, color='lightgreen')
plt.title('Distribution of Prices (Log Transformed)')
plt.xlabel('Log(Price)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# * np.log1p(x): This function computes the natural logarithm of 1+x. It's designed to provide more accurate results for values of x that are very close to zero.
#
# * Using np.log1p helps in transforming the price column while ensuring that any value (including zero, if present) is handled appropriately. When we need to reverse the transformation, we can use np.expm1 which computes e^x-1

# %%
skewness = np.log1p(df['price']).skew()
kurtosis = np.log1p(df['price']).kurt()

print(skewness,kurtosis)
# Out:
# 1.0753237997537126 0.9753290631822202

# %%
plt.figure(figsize=(15, 6))

# Distribution plot without log transformation
plt.subplot(1, 2, 1)
sns.boxplot(df['price'], color='skyblue')
plt.title('Distribution of Prices (Original)')
plt.xlabel('Price (in Crores)')
plt.ylabel('Frequency')

# Distribution plot with log transformation
plt.subplot(1, 2, 2)
sns.boxplot(np.log1p(df['price']), color='lightgreen')
plt.title('Distribution of Prices (Log Transformed)')
plt.xlabel('Log(Price)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
#price_per_sqft
df['price_per_sqft'].isnull().sum()
# Out:
# np.int64(1)

# %%
df['price_per_sqft'].describe()
# Out:
# count      3797.000000
# mean      13832.838820
# std       23029.342253
# min           4.000000
# 25%        6812.000000
# 50%        9011.000000
# 75%       13870.000000
# max      600000.000000
# Name: price_per_sqft, dtype: float64

# %%
sns.histplot(df['price_per_sqft'], bins=50, color='skyblue', kde=True)
# Out:
# <Axes: xlabel='price_per_sqft', ylabel='Count'>

# %% [markdown]
# * Most properties have a price_per_sqft ranging between approximately ₹0 and ₹40,000. There is a significant concentration in the lower range, with a few properties having exceptionally high price_per_sqft.

# %%
sns.boxplot(df['price_per_sqft'], color='lightgreen')
# Out:
# <Axes: ylabel='price_per_sqft'>

# %% [markdown]
# * The box plot clearly shows several outliers, especially on the higher side. The interquartile range (IQR) is relatively compact, but there are many data points beyond the "whiskers" of the box plot, indicating potential outliers
#
# # Observations
# * Potential Outliers
# * Right Skewed
# * 1 missing values

# %%
#bedRoom
df['bedRoom'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['bedRoom'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].value_counts(normalize=True).head().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='proportion'>

# %%
#bathroom
df['bathroom'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['bathroom'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='bathroom'>

# %%
df['bathroom'].value_counts(normalize=True).head().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='proportion'>

# %%
#balcony
df['balcony'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['balcony'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='balcony'>

# %%
df['balcony'].value_counts(normalize=True).head().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='proportion'>

# %%
### floorNum

# %%
df.iloc[:,10:].head()
# Out:
#    floorNum      facing   agePossession  super_built_up_area  built_up_area  \
# 0       3.0        East  Relatively New               2691.0         2460.0
# 1       8.0  North-West  Moderately Old               1854.0         1668.0
# 2      23.0  North-West  Relatively New                  NaN            NaN
# 3       5.0        East  Relatively New               2361.0            NaN
# 4      10.0  South-East    New Property                  NaN            NaN
#
#    carpet_area  study room  servant room  store room  pooja room  others  \
# 0       2100.0           0             1           0           0       0
# 1       1501.0           0             1           0           1       0
# 2       2864.0           1             1           0           1       1
# 3          NaN           0             1           1           0       0
# 4       3000.0           0             1           0           1       0
#
#    furnishing_type  luxury_score
# 0                0           167
# ...

# %%
df['floorNum'].isnull().sum()
# Out:
# np.int64(19)

# %%
df['floorNum'].describe()
# Out:
# count    3779.000000
# mean        6.815030
# std         6.029873
# min         0.000000
# 25%         2.000000
# 50%         5.000000
# 75%        10.000000
# max        51.000000
# Name: floorNum, dtype: float64

# %%
df['floorNum'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='floorNum'>

# %%
sns.boxplot(df['floorNum'], color='lightgreen')
# Out:
# <Axes: ylabel='floorNum'>

# %% [markdown]
# * The majority of the properties lie between the ground floor (0) and the 25th
# floor.
# * Floors 1 to 4 are particularly common, with the 3rd floor being the most frequent.
# * There are a few properties located at higher floors, but their frequency is much lower.
# * The box plot reveals that the majority of the properties are concentrated around the lower floors. The interquartile range (IQR) lies between approximately the 2nd and 10th floors.
# * Data points beyond the "whiskers" of the box plot, especially on the higher side, indicate potential outliers.

# %%
# facing
df['facing'].isnull().sum()
# Out:
# np.int64(1099)

# %%
df['facing'].fillna('NA',inplace=True)
# Out:
# <ipython-input-90-e6ba103970bd>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['facing'].fillna('NA',inplace=True)

# %%
df['facing'].value_counts()
# Out:
# facing
# NA            1099
# East           643
# North-East     638
# North          401
# West           252
# South          235
# North-West     199
# South-East     173
# South-West     158
# Name: count, dtype: int64

# %%
# agePossession
df['agePossession'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1671
# New Property           625
# Moderately Old         576
# Undefined              340
# Old Property           312
# Under Construction     274
# Name: count, dtype: int64

# %% [markdown]
# # **areas**

# %%
# super built up area
df['super_built_up_area'].isnull().sum()
# Out:
# np.int64(1883)

# %%
df['super_built_up_area'].describe()
# Out:
# count     1915.000000
# mean      1921.658251
# std        767.160169
# min         89.000000
# 25%       1457.000000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
sns.histplot(df['super_built_up_area'].dropna(), bins=50, color='skyblue', kde=True)
# Out:
# <Axes: xlabel='super_built_up_area', ylabel='Count'>

# %%
sns.boxplot(df['super_built_up_area'].dropna(), color='lightgreen')
# Out:
# <Axes: ylabel='super_built_up_area'>

# %% [markdown]
# * Most properties have a super built-up area ranging between approximately 1,000 sq.ft and 2,500 sq.ft.
# * There are a few properties with a significantly larger area, leading to a right-skewed distribution.
# * The interquartile range (IQR) lies between roughly 1,480 sq.ft and 2,215 sq.ft, indicating that the middle 50% of the properties fall within this range.
# * There are several data points beyond the upper "whisker" of the box plot, indicating potential outliers. These are properties with an unusually large super built-up area.

# %%
# built up area
df['built_up_area'].isnull().sum()
# Out:
# np.int64(2070)

# %%
df['built_up_area'].describe()
# Out:
# count      1728.00000
# mean       2372.38563
# std       17744.12842
# min           2.00000
# 25%        1120.00000
# 50%        1650.00000
# 75%        2400.00000
# max      737147.00000
# Name: built_up_area, dtype: float64

# %%
sns.histplot(df['built_up_area'].dropna(), bins=50, color='skyblue', kde=False)
# Out:
# <Axes: xlabel='built_up_area', ylabel='Count'>

# %%
sns.boxplot(df['built_up_area'].dropna(), color='lightgreen')
# Out:
# <Axes: ylabel='built_up_area'>

# %% [markdown]
# * Most properties have a built-up area ranging roughly between 500 sq.ft and 3,500 sq.ft.
# * There are very few properties with a much larger built-up area, leading to a highly right-skewed distribution.
# * The box plot confirms the presence of significant outliers on the higher side. The data's interquartile range (IQR) is relatively compact, but the "whiskers" of the box plot are stretched due to the outliers.
#
# **The presence of extreme values, especially on the higher side, suggests that there may be outliers or data errors. This could also be due to some properties being exceptionally large, like a commercial complex or an entire building being listed.**

# %%
# carpet area
df['carpet_area'].isnull().sum()
# Out:
# np.int64(1856)

# %%
df['carpet_area'].describe()
# Out:
# count      1942.000000
# mean       2485.692450
# std       22386.656294
# min          15.000000
# 25%         825.500000
# 50%        1294.500000
# 75%        1788.750000
# max      607936.000000
# Name: carpet_area, dtype: float64

# %%
sns.histplot(df['carpet_area'].dropna(), bins=50, color='skyblue', kde=False)
# Out:
# <Axes: xlabel='carpet_area', ylabel='Count'>

# %%
sns.boxplot(df['carpet_area'].dropna(), color='lightgreen')
# Out:
# <Axes: ylabel='carpet_area'>

# %%
df.iloc[:,16:]
# Out:
#       study room  servant room  store room  pooja room  others  \
# 0              0             1           0           0       0
# 1              0             1           0           1       0
# 2              1             1           0           1       1
# 3              0             1           1           0       0
# 4              0             1           0           1       0
# ...          ...           ...         ...         ...     ...
# 3794           0             0           0           0       0
# 3795           1             0           0           0       0
# 3796           1             1           0           0       0
# 3797           0             0           0           0       0
# 3798           0             1           0           1       0
#
#       furnishing_type  luxury_score
# 0                   0           167
# 1                   0           111
# 2                   2            49
# 3                   2           174
# ...

# %%
# additional rooms
plt.figure(figsize=(20, 12))

# Create a subplot of pie charts for each room type
for idx, room in enumerate(['study room','servant room','store room','pooja room','others'], 1):
    ax = plt.subplot(2, 3, idx)
    df[room].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, ax=ax)
    plt.title(f'Distribution of {room.title()}')
    plt.ylabel('')

plt.tight_layout()
plt.show()

# %%
# furnishing_type
df['furnishing_type'].value_counts()
# Out:
# furnishing_type
# 0    2504
# 2    1081
# 1     213
# Name: count, dtype: int64

# %%
df['furnishing_type'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# luxury score
df['luxury_score'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['luxury_score'].describe()
# Out:
# count    3798.000000
# mean       71.014218
# std        52.822333
# min         0.000000
# 25%        31.000000
# 50%        58.000000
# 75%       109.000000
# max       174.000000
# Name: luxury_score, dtype: float64

# %%
sns.histplot(df['luxury_score'], bins=50, color='skyblue', kde=True)
# Out:
# <Axes: xlabel='luxury_score', ylabel='Count'>

# %%
sns.boxplot(df['luxury_score'], color='lightgreen')
# Out:
# <Axes: ylabel='luxury_score'>

# %% [markdown]
# * The luxury score distribution has multiple peaks, suggesting a multi-modal distribution. There's a significant number of properties with lower luxury scores (around 0-50), and another peak is observed around the 110-130 range.
#
# * The box plot reveals that the majority of the properties have luxury scores between approximately 30 and 110. The interquartile range (IQR) lies between these values.

# %%
df.head()
# Out:
#   property_type                  society      sector  price  price_per_sqft  \
# 0          flat  la vida by tata housing  sector 113   3.00         14285.0
# 1          flat     umang monsoon breeze   sector 78   0.88          4746.0
# 2          flat      ireo the grand arch   sector 58   4.85         16934.0
# 3          flat            m3m woodshire  sector 107   1.49          6310.0
# 4          flat       ambience creacions   sector 22   6.16         20533.0
#
#      area                                       areaWithType  bedRoom  \
# 0  2100.0  Super Built up area 2691(250 sq.m.)Built Up ar...        3
# 1  1854.0  Super Built up area 1854(172.24 sq.m.)Built Up...        3
# 2  2864.0                   Carpet area: 2864 (266.07 sq.m.)        4
# 3  2361.0             Super Built up area 2361(219.34 sq.m.)        3
# 4  3000.0                   Carpet area: 3000 (278.71 sq.m.)        4
#
#    bathroom balcony  ...  super_built_up_area built_up_area carpet_area  \
# ...
